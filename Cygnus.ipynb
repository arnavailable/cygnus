# %%
# Download the required packages
# !pip install -r requirements.txt
# Out:
# Collecting networkx==2.8.6 (from -r requirements.txt (line 1))
#   Obtaining dependency information for networkx==2.8.6 from https://files.pythonhosted.org/packages/be/25/5b0fc262a2f2d7d11c22cb7785edf2befc756ae076b383034e79e255eb11/networkx-2.8.6-py3-none-any.whl.metadata
#   Downloading networkx-2.8.6-py3-none-any.whl.metadata (5.0 kB)
# Collecting numpy==1.23.3 (from -r requirements.txt (line 2))
#   Obtaining dependency information for numpy==1.23.3 from https://files.pythonhosted.org/packages/b1/84/0af94541d21dd2d403377209f462b6b463dc4ba15158776285f1af2132ac/numpy-1.23.3-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading numpy-1.23.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.3 kB)
# Collecting pandas==1.4.4 (from -r requirements.txt (line 3))
#   Downloading pandas-1.4.4.tar.gz (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 18.1 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pyvis==0.2.1 (from -r requirements.txt (line 4))
#   Downloading pyvis-0.2.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting streamlit==1.12.2 (from -r requirements.txt (line 5))
#   Obtaining dependency information for streamlit==1.12.2 from https://files.pythonhosted.org/packages/46/73/0b497b5dbf99079c7f70dab726798945390477f1fd3a6b036188e1a3b90c/streamlit-1.12.2-py2.py3-none-any.whl.metadata
#   Downloading streamlit-1.12.2-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: snowflake-connector-python==3.13.2 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (3.13.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from pandas==1.4.4->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from pandas==1.4.4->-r requirements.txt (line 3)) (2023.3.post1)
# Requirement already satisfied: jinja2>=2.9.6 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from pyvis==0.2.1->-r requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: ipython>=5.3.0 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from pyvis==0.2.1->-r requirements.txt (line 4)) (8.15.0)
# Collecting jsonpickle>=1.4.1 (from pyvis==0.2.1->-r requirements.txt (line 4))
#   Obtaining dependency information for jsonpickle>=1.4.1 from https://files.pythonhosted.org/packages/86/7c/c06580145924f60342f669f6e71905f838083d00e4b141172a75d22a23fc/jsonpickle-4.0.1-py3-none-any.whl.metadata
#   Downloading jsonpickle-4.0.1-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: altair>=3.2.0 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from streamlit==1.12.2->-r requirements.txt (line 5)) (4.2.2)
# Requirement already satisfied: blinker>=1.0.0 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from streamlit==1.12.2->-r requirements.txt (line 5)) (1.8.2)
# Requirement already satisfied: cachetools>=4.0 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from streamlit==1.12.2->-r requirements.txt (line 5)) (5.3.3)
# Requirement already satisfied: click>=7.0 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from streamlit==1.12.2->-r requirements.txt (line 5)) (8.0.4)
# Requirement already satisfied: importlib-metadata>=1.4 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from streamlit==1.12.2->-r requirements.txt (line 5)) (6.0.0)
# Requirement already satisfied: packaging>=14.1 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from streamlit==1.12.2->-r requirements.txt (line 5)) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from streamlit==1.12.2->-r requirements.txt (line 5)) (9.5.0)
# Collecting protobuf<4,>=3.12 (from streamlit==1.12.2->-r requirements.txt (line 5))
#   Obtaining dependency information for protobuf<4,>=3.12 from https://files.pythonhosted.org/packages/8d/14/619e24a4c70df2901e1f4dbc50a6291eb63a759172558df326347dce1f0d/protobuf-3.20.3-py2.py3-none-any.whl.metadata
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Requirement already satisfied: pyarrow>=4.0 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from streamlit==1.12.2->-r requirements.txt (line 5)) (11.0.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from streamlit==1.12.2->-r requirements.txt (line 5)) (0.9.1)
# Requirement already satisfied: pympler>=0.9 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from streamlit==1.12.2->-r requirements.txt (line 5)) (1.1)
# Requirement already satisfied: requests>=2.4 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from streamlit==1.12.2->-r requirements.txt (line 5)) (2.31.0)
# Requirement already satisfied: rich>=10.11.0 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from streamlit==1.12.2->-r requirements.txt (line 5)) (13.7.1)
# Collecting semver (from streamlit==1.12.2->-r requirements.txt (line 5))
#   Obtaining dependency information for semver from https://files.pythonhosted.org/packages/a6/24/4d91e05817e92e3a61c8a21e08fd0f390f5301f1c448b137c57c4bc6e543/semver-3.0.4-py3-none-any.whl.metadata
#   Downloading semver-3.0.4-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: toml in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from streamlit==1.12.2->-r requirements.txt (line 5)) (0.10.2)
# Requirement already satisfied: tornado>=5.0 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from streamlit==1.12.2->-r requirements.txt (line 5)) (6.3.2)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from streamlit==1.12.2->-r requirements.txt (line 5)) (4.12.2)
# Requirement already satisfied: tzlocal>=1.1 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from streamlit==1.12.2->-r requirements.txt (line 5)) (4.3.1)
# Requirement already satisfied: validators>=0.2 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from streamlit==1.12.2->-r requirements.txt (line 5)) (0.33.0)
# Requirement already satisfied: gitpython!=3.1.19 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from streamlit==1.12.2->-r requirements.txt (line 5)) (3.1.43)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python==3.13.2->-r requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python==3.13.2->-r requirements.txt (line 6)) (1.15.1)
# Requirement already satisfied: cryptography>=3.1.0 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python==3.13.2->-r requirements.txt (line 6)) (43.0.0)
# Requirement already satisfied: pyOpenSSL<25.0.0,>=22.0.0 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python==3.13.2->-r requirements.txt (line 6)) (24.2.1)
# Requirement already satisfied: pyjwt<3.0.0 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python==3.13.2->-r requirements.txt (line 6)) (2.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python==3.13.2->-r requirements.txt (line 6)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python==3.13.2->-r requirements.txt (line 6)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python==3.13.2->-r requirements.txt (line 6)) (2023.11.17)
# Requirement already satisfied: filelock<4,>=3.5 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python==3.13.2->-r requirements.txt (line 6)) (3.9.0)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python==3.13.2->-r requirements.txt (line 6)) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python==3.13.2->-r requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: tomlkit in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python==3.13.2->-r requirements.txt (line 6)) (0.11.1)
# Requirement already satisfied: entrypoints in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from altair>=3.2.0->streamlit==1.12.2->-r requirements.txt (line 5)) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from altair>=3.2.0->streamlit==1.12.2->-r requirements.txt (line 5)) (4.17.3)
# Requirement already satisfied: toolz in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from altair>=3.2.0->streamlit==1.12.2->-r requirements.txt (line 5)) (0.12.0)
# Requirement already satisfied: pycparser in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python==3.13.2->-r requirements.txt (line 6)) (2.21)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from gitpython!=3.1.19->streamlit==1.12.2->-r requirements.txt (line 5)) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from importlib-metadata>=1.4->streamlit==1.12.2->-r requirements.txt (line 5)) (3.11.0)
# Requirement already satisfied: backcall in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.2.1->-r requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: decorator in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.2.1->-r requirements.txt (line 4)) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.2.1->-r requirements.txt (line 4)) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.2.1->-r requirements.txt (line 4)) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.2.1->-r requirements.txt (line 4)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.2.1->-r requirements.txt (line 4)) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.2.1->-r requirements.txt (line 4)) (2.15.1)
# Requirement already satisfied: stack-data in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.2.1->-r requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.2.1->-r requirements.txt (line 4)) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.2.1->-r requirements.txt (line 4)) (4.8.0)
# Requirement already satisfied: appnope in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.2.1->-r requirements.txt (line 4)) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from jinja2>=2.9.6->pyvis==0.2.1->-r requirements.txt (line 4)) (2.1.1)
# Requirement already satisfied: six>=1.5 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas==1.4.4->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from requests>=2.4->streamlit==1.12.2->-r requirements.txt (line 5)) (1.26.16)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->streamlit==1.12.2->-r requirements.txt (line 5)) (2.2.0)
# Requirement already satisfied: pytz-deprecation-shim in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from tzlocal>=1.1->streamlit==1.12.2->-r requirements.txt (line 5)) (0.1.0.post0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit==1.12.2->-r requirements.txt (line 5)) (5.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis==0.2.1->-r requirements.txt (line 4)) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.12.2->-r requirements.txt (line 5)) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.12.2->-r requirements.txt (line 5)) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->streamlit==1.12.2->-r requirements.txt (line 5)) (0.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis==0.2.1->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.3.0->pyvis==0.2.1->-r requirements.txt (line 4)) (0.2.5)
# Requirement already satisfied: tzdata in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit==1.12.2->-r requirements.txt (line 5)) (2023.3)
# Requirement already satisfied: executing in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis==0.2.1->-r requirements.txt (line 4)) (0.8.3)
# Requirement already satisfied: asttokens in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis==0.2.1->-r requirements.txt (line 4)) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/arnavgarg/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis==0.2.1->-r requirements.txt (line 4)) (0.2.2)
# Downloading networkx-2.8.6-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 30.0 MB/s eta 0:00:00a 0:00:01
# Downloading numpy-1.23.3-cp311-cp311-macosx_11_0_arm64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 10.3 MB/s eta 0:00:0000:0100:01
# Downloading streamlit-1.12.2-py2.py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 31.5 MB/s eta 0:00:00a 0:00:01
# Downloading jsonpickle-4.0.1-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 6.6 MB/s eta 0:00:00
# Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 21.3 MB/s eta 0:00:00
# Downloading semver-3.0.4-py3-none-any.whl (17 kB)
# Building wheels for collected packages: pandas, pyvis
#   Building wheel for pandas (pyproject.toml) ... done
#   Created wheel for pandas: filename=pandas-1.4.4-cp311-cp311-macosx_11_0_arm64.whl size=9812465 sha256=f5ebbd4045d877bcb209b400e8b5ecb15d731a2c4d8db655a77544e9e60a4053
#   Stored in directory: /Users/arnavgarg/Library/Caches/pip/wheels/56/ff/8e/5497c17f51e61a95c9cf4c58914222f311ca968796ee52d430
#   Building wheel for pyvis (setup.py) ... done
#   Created wheel for pyvis: filename=pyvis-0.2.1-py3-none-any.whl size=23668 sha256=488484c9a20f23dd1ff6a2608093654564e95c74efffa27ba8b201e59dc8cc6e
#   Stored in directory: /Users/arnavgarg/Library/Caches/pip/wheels/1b/49/fa/a25effbd7cf85f7de92105b60a7e94314d354010d2347fb383
# Successfully built pandas pyvis
# Installing collected packages: semver, protobuf, numpy, networkx, jsonpickle, pandas, streamlit, pyvis
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.3
#     Uninstalling protobuf-4.25.3:
#       Successfully uninstalled protobuf-4.25.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.1
#     Uninstalling networkx-3.1:
#       Successfully uninstalled networkx-3.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
#   Attempting uninstall: streamlit
#     Found existing installation: streamlit 1.39.0
#     Uninstalling streamlit-1.39.0:
#       Successfully uninstalled streamlit-1.39.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# opencv-python 4.10.0.84 requires numpy>=1.23.5; python_version >= "3.11", but you have numpy 1.23.3 which is incompatible.
# st-theme 1.2.2 requires streamlit>=1.20, but you have streamlit 1.12.2 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.23.3 which is incompatible.
# streamlit-vertical-slider 2.5.5 requires streamlit>=1.22.0, but you have streamlit 1.12.2 which is incompatible.
# grpcio-status 1.62.2 requires protobuf>=4.21.6, but you have protobuf 3.20.3 which is incompatible.
# faiss-cpu 1.9.0 requires numpy<3.0,>=1.25.0, but you have numpy 1.23.3 which is incompatible.
# blis 1.0.1 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.23.3 which is incompatible.
# thinc 8.3.2 requires numpy<2.1.0,>=2.0.0; python_version >= "3.9", but you have numpy 1.23.3 which is incompatible.
# Successfully installed jsonpickle-4.0.1 networkx-2.8.6 numpy-1.23.3 pandas-1.4.4 protobuf-3.20.3 pyvis-0.2.1 semver-3.0.4 streamlit-1.12.2

# %%
# Import all the necessary libraries
import numpy as np
import pandas as pd
import streamlit as st
import streamlit.components.v1 as components
import networkx as nx
import snowflake.connector
from pyvis.network import Network
import matplotlib.pyplot as plt

# %%
# Snowflake Connection
conn = snowflake.connector.connect(
    user = st.secrets["USER"],
    password = st.secrets["PASSWORD"],
    account = st.secrets["ACCOUNT"],
    warehouse = st.secrets["WAREHOUSE"],
    database = st.secrets["DATABASE"],
    schema = st.secrets["SCHEMA"]
)

# Query to get the data
query = """
WITH transaction_paths AS (
    -- Step 1: Start with all transactions as starting points
    SELECT 
        sender_account AS start_account,
        beneficiary_account AS current_account,
        transaction_amount AS start_amount,
        transaction_amount AS current_amount,
        transaction_date AS start_date,
        transaction_date AS current_date,
        ARRAY_CONSTRUCT(sender_account, beneficiary_account) AS account_path,
        ARRAY_CONSTRUCT(transaction_date) AS date_path,
        ARRAY_CONSTRUCT(transaction_amount) AS amount_path,
        ARRAY_CONSTRUCT(transaction_id) AS id_path,
        1 AS depth
    FROM "CYGNUS"."PUBLIC"."TRANSACTIONS"

    UNION ALL

    -- Step 2: Extend paths by finding valid next transactions
    SELECT 
        tp.start_account,
        t.beneficiary_account,
        tp.start_amount,
        t.transaction_amount,
        tp.start_date,
        t.transaction_date,
        ARRAY_APPEND(tp.account_path, t.beneficiary_account),
        ARRAY_APPEND(tp.date_path, t.transaction_date),
        ARRAY_APPEND(tp.amount_path, t.transaction_amount),
        ARRAY_APPEND(tp.id_path, t.transaction_id),
        tp.depth + 1
    FROM transaction_paths tp,
         LATERAL (
            SELECT *
            FROM "CYGNUS"."PUBLIC"."TRANSACTIONS" t
            WHERE tp.current_account = t.sender_account
            AND t.transaction_date > tp.current_date
            AND t.transaction_amount BETWEEN tp.current_amount * 0.9 AND tp.current_amount * 1.1
            AND NOT ARRAY_CONTAINS(tp.account_path, ARRAY_CONSTRUCT(t.beneficiary_account)) -- Prevent cycles before completing loop
        ) t
)
SELECT account_path, date_path, amount_path, id_path, depth
FROM transaction_paths
WHERE current_account = start_account  -- Ensure loop completion
AND depth > 2  -- At least one intermediate transaction
ORDER BY start_date
"""

# Execute the query
cur = conn.cursor()
cur.execute(query)

# Fetch the data
rows = cur.fetchall()

# Create a dataframe
df = pd.DataFrame(rows, columns=[x[0] for x in cur.description])

# Close the cursor and connection
cur.close()
conn.close()
# Out:
# 2025-02-07 20:52:58.031 INFO    snowflake.connector.connection: Snowflake Connector for Python Version: 3.13.2, Python Version: 3.11.5, Platform: macOS-15.3-arm64-arm-64bit
# 2025-02-07 20:52:58.032 INFO    snowflake.connector.connection: Connecting to GLOBAL Snowflake domain
# 2025-02-07 20:52:58.032 INFO    snowflake.connector.connection: This connection is in OCSP Fail Open Mode. TLS Certificates would be checked for validity and revocation status. Any other Certificate Revocation related exceptions or OCSP Responder failures would be disregarded in favor of connectivity.
# 2025-02-07 20:52:58.855 INFO    snowflake.connector.connection: closed
# 2025-02-07 20:52:58.903 INFO    snowflake.connector.connection: No async queries seem to be running, deleting session

# %%
df
# Out:
#        transaction_id sender_account beneficiary_account transaction_date  \
# index
# 0                9007    Account_493         Account_604       2024-01-05
# 0                5533    Account_604          Account_42       2024-06-27
# 0                4624     Account_42         Account_493       2024-11-24
# 1                  26    Account_548         Account_711       2024-01-08
# 1                6455    Account_711         Account_471       2024-02-04
# 1                4909    Account_471         Account_617       2024-04-02
# 1                9886    Account_617         Account_548       2024-12-02
# 2                3174    Account_359         Account_387       2024-01-31
# 2                2946    Account_387         Account_594       2024-05-08
# 2                1153    Account_594         Account_359       2024-10-09
# 3                6688    Account_255         Account_748       2024-02-21
# 3                7982    Account_748         Account_481       2024-03-23
# 3                3914    Account_481         Account_255       2024-11-04
# 4                  19    Account_657         Account_104       2024-04-27
# 4                5488    Account_104         Account_298       2024-04-30
# 4                3902    Account_298         Account_657       2024-05-03
# 5                2158    Account_380         Account_451       2024-09-08
# 5                5669    Account_451         Account_136       2024-11-04
# 5                7218    Account_136         Account_380       2024-12-18
#
#        transaction_amount
# index
# 0                  597.79
# 0                  560.92
# 0                  518.29
# 1                  600.01
# 1                  630.80
# 1                  662.22
# 1                  636.55
# 2                  954.55
# 2                  936.17
# 2                  926.46
# 3                  424.05
# 3                  442.67
# 3                  437.70
# 4                  482.91
# 4                  477.93
# 4                  431.04
# 5                  656.38
# 5                  672.67
# 5                  633.42

# %%
# Process the output
df.columns = ['path', 'date_path', 'amount_path', 'id_path', 'depth']

# Clean path, date_path, and amount_path columns by removing \n from array
df['path'] = df['path'].apply(lambda x: eval(x))
df['date_path'] = df['date_path'].apply(lambda x: eval(x))
df['amount_path'] = df['amount_path'].apply(lambda x: eval(x))
df['id_path'] = df['id_path'].apply(lambda x: eval(x))

# %%
# Expand lists into rows while keeping the original index
rows = []
for idx, row in df.iterrows():
    for i in range(len(row["date_path"])):
        rows.append([
            idx,  # Preserve original index
            row["id_path"][i],
            row["path"][i],
            row["path"][i + 1],
            row["date_path"][i],
            row["amount_path"][i]
        ])

# Create new DataFrame
df = pd.DataFrame(rows, columns=["index", "transaction_id", "sender_account", "beneficiary_account", "transaction_date", "transaction_amount"]).set_index("index")

# %%
df

# calculate %diff from previous row if index is same
df['amount_diff'] = df.groupby('index')['transaction_amount'].pct_change()*100

df
# Out:
#        transaction_id sender_account beneficiary_account transaction_date  \
# index
# 0                9007    Account_493         Account_604       2024-01-05
# 0                5533    Account_604          Account_42       2024-06-27
# 0                4624     Account_42         Account_493       2024-11-24
# 1                  26    Account_548         Account_711       2024-01-08
# 1                6455    Account_711         Account_471       2024-02-04
# 1                4909    Account_471         Account_617       2024-04-02
# 1                9886    Account_617         Account_548       2024-12-02
# 2                3174    Account_359         Account_387       2024-01-31
# 2                2946    Account_387         Account_594       2024-05-08
# 2                1153    Account_594         Account_359       2024-10-09
# 3                6688    Account_255         Account_748       2024-02-21
# 3                7982    Account_748         Account_481       2024-03-23
# 3                3914    Account_481         Account_255       2024-11-04
# 4                  19    Account_657         Account_104       2024-04-27
# 4                5488    Account_104         Account_298       2024-04-30
# 4                3902    Account_298         Account_657       2024-05-03
# 5                2158    Account_380         Account_451       2024-09-08
# 5                5669    Account_451         Account_136       2024-11-04
# 5                7218    Account_136         Account_380       2024-12-18
#
#        transaction_amount  amount_diff
# index
# 0                  597.79          NaN
# 0                  560.92    -6.167718
# 0                  518.29    -7.600014
# 1                  600.01          NaN
# 1                  630.80     5.131581
# 1                  662.22     4.980977
# 1                  636.55    -3.876355
# 2                  954.55          NaN
# 2                  936.17    -1.925515
# 2                  926.46    -1.037205
# 3                  424.05          NaN
# 3                  442.67     4.390992
# 3                  437.70    -1.122733
# 4                  482.91          NaN
# 4                  477.93    -1.031248
# 4                  431.04    -9.811060
# 5                  656.38          NaN
# 5                  672.67     2.481794
# 5                  633.42    -5.834956

# %%
import streamlit as st
import networkx as nx
from pyvis.network import Network
import pandas as pd
import streamlit.components.v1 as components

# # Sample dataframe (replace with actual df)
# df = pd.DataFrame({
#     'account_send': ['A', 'B', 'C', 'D', 'E'],
#     'account_receive': ['B', 'C', 'D', 'E', 'A'],
#     'amount': [100, 200, 150, 300, 250],
#     'date': ['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04', '2024-01-05']
# })

# Set header title
st.title('Network Graph Visualization of Transaction Loops')

# Define list of selection options
suspicious_accounts = df.account_send.unique()
suspicious_accounts.sort()

# Implement selection box for account visualization
selected_account = st.selectbox('Select account to visualize', suspicious_accounts)

if selected_account:
    # Filter data for selected account
    df_select = df[(df.account_send == selected_account) | (df.account_receive == selected_account)]

    # Create a directed graph
    G = nx.DiGraph()

    # Add nodes and edges with attributes
    for _, row in df_select.iterrows():
        sender_color = "#4CAF50"  # Green for intermediary accounts
        receiver_color = "#2196F3"  # Blue for origination accounts

        G.add_node(row["account_send"], label=str(row["account_send"]), color=sender_color)
        G.add_node(row["account_receive"], label=str(row["account_receive"]), color=receiver_color)
        G.add_edge(
            row["account_send"], row["account_receive"],
            title=f"Amount: ${row['amount']}<br>Date: {row['date']}",
            label=f"${row['amount']}\n{row['date']}",
            color="#FF9800"
        )

    # Create PyVis Network
    account_network = Network(height="500px", width="100%", directed=True, bgcolor="#222222", font_color="white")

    # Convert NetworkX graph to PyVis
    account_network.from_nx(G)

    # Improve layout with physics settings
    account_network.repulsion(node_distance=300, central_gravity=0.3, spring_length=100, spring_strength=0.1, damping=0.9)

    # Ensure edge labels are always visible
    for edge in account_network.edges:
        edge["font"] = {"size": 12, "color": "white", "background": "black"}

    # Add legend manually
    account_network.add_node("Origination Account", color="#2196F3", shape="dot", size=10)
    account_network.add_node("Intermediary Accounts", color="#4CAF50", shape="dot", size=10)

    # Save and read graph as HTML file
    path = '/tmp' if 'tmp' in dir() else '/html_files'
    account_network.save_graph(f'{path}/pyvis_graph.html')
    HtmlFile = open(f'{path}/pyvis_graph.html', 'r', encoding='utf-8')

    # Display graph in Streamlit
    components.html(HtmlFile.read(), height=500)

    # Show filtered dataframe below the graph
    st.subheader(f"Transaction Details for Account: {selected_account}")
    st.dataframe(df_select)

# %%
# Set header title
st.title('Network Graph Visualization of Transaction Loops')

# Define list of selection options
suspicious_accounts = df.account_send.unique()
suspicious_accounts.sort()

# Implement multiselect dropdown menu for option selection (returns a list)
selected_account = st.selectbox('Select account to visualize', suspicious_accounts)

# Set info message on initial site load
if selected_account:
    st.text('Choose an account to start')

# Create network graph when user selects >= 1 item
else:
    df_select = df[df.index == df[df.account_send == selected_account].index[0]]

    # Create a directed graph
    G = nx.DiGraph()

    # Add nodes and edges with attributes
    for _, row in df_select.iterrows():
        G.add_node(row["account_send"], label=str(row["account_send"]), color="#4CAF50")  # Green sender
        G.add_node(row["account_receive"], label=str(row["account_receive"]), color="#2196F3")  # Blue receiver
        G.add_edge(
            row["account_send"], row["account_receive"],
            title=f"Amount: ${row['amount']}\nDate: {row['date']}",  # Tooltip when hovering
            label=f"${row['amount']}\n{row['date']}",  # Visible label
            color="#FF9800"  # Orange edges
        )

    # Create PyVis Network
    account_network = Network(height="500px", width="100%", directed=True, bgcolor="#222222", font_color="white")

    # Convert NetworkX graph to PyVis
    account_network.from_nx(G)

    # Improve layout with physics settings
    account_network.repulsion(node_distance=300, central_gravity=0.3, spring_length=100, spring_strength=0.1, damping=0.9)

    # Force edge labels to show
    for edge in account_network.edges:
        edge["font"] = {"size": 12, "color": "white", "background": "black"}

    # Save and read graph as HTML file (on Streamlit Sharing)
    try:
        path = '/tmp'
        account_network.save_graph(f'{path}/pyvis_graph.html')
        HtmlFile = open(f'{path}/pyvis_graph.html', 'r', encoding='utf-8')

    # Save and read graph as HTML file (locally)
    except:
        path = '/html_files'
        account_network.save_graph(f'{path}/pyvis_graph.html')
        HtmlFile = open(f'{path}/pyvis_graph.html', 'r', encoding='utf-8')

    # Load HTML file in HTML component for display on Streamlit page
    components.html(HtmlFile.read(), height=435)
# Out:
# 2025-02-07 19:27:55.828
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/arnavgarg/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py [ARGUMENTS]

# %%
# # Sample data
# df = df.copy()

# # Initialize directed graph
# G = nx.DiGraph()

# # Add edges to the graph
# for row in range(3):
#     path, dates, amounts = df['path'][row], df['date_path'][row], df['amount_path'][row]
#     for i in range(len(dates)):
#         G.add_edge(path[i], path[i + 1], date=dates[i], amount=amounts[i])

# # # Draw the graph
# # pos = nx.circular_layout(G)  # Layout
# # plt.figure(figsize=(6, 6))
# # nx.draw(G, pos, with_labels=True, node_color="lightblue", edge_color="gray", node_size=2000, font_size=10)

# # # Add edge labels (date and amount)
# # edge_labels = {(u, v): f"{d['date']}\n${d['amount']}" for u, v, d in G.edges(data=True)}
# # nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=8)

# # plt.title("Transaction Loops")
# # plt.show()
